# %% [markdown]
# <a href="https://colab.research.google.com/github/King-Abbey/King-Abbey/blob/main/Data%20Prepossessing%20%26%20VisualizationCheckpoint_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('/content/drive/MyDrive/titanic-passengers.csv', encoding = "ISO8859-1")
df.head()
# Out:
#                    PassengerId;Survived;Pclass;Name;Sex;Age;SibSp;Parch;Ticket;Fare;Cabin;Embarked
# 343;No;2;Collander       Mr. Erik Gustaf;male;28.0;0;0;248740;13.0;;S
# 76;No;3;Moen         Mr. Sigurd Hansen;male;25.0;0;0;348123;7.65;F...
# 641;No;3;Jensen      Mr. Hans Peder;male;20.0;0;0;350050;7.8542000...
# 568;No;3;Palsson     Mrs. Nils (Alma Cornelia Berglund);female;29....
# 672;No;1;Davidson    Mr. Thornton;male;31.0;1;0;F.C. 12750;52.0;B71;S

# %%
# finding missing value

# %%
df.isnull().sum()
# Out:
# PassengerId;Survived;Pclass;Name;Sex;Age;SibSp;Parch;Ticket;Fare;Cabin;Embarked    0
# dtype: int64

# %%
# There is an issue with the Dataset given

# %%
# Importing a New Dataset

# %%
df = pd.read_csv('/content/test.csv', encoding = "ISO8859-1")
df.head()
# Out:
#    Unnamed: 0     id  ... Arrival Delay in Minutes             satisfaction
# 0           0  19556  ...                     44.0                satisfied
# 1           1  90035  ...                      0.0                satisfied
# 2           2  12360  ...                      0.0  neutral or dissatisfied
# 3           3  77959  ...                      6.0                satisfied
# 4           4  36875  ...                     20.0                satisfied
#
# [5 rows x 25 columns]

# %%
# Finding Missing Value

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                            0
# id                                    0
# Gender                                0
# Customer Type                         0
# Age                                   0
# Type of Travel                        0
# Class                                 0
# Flight Distance                       0
# Inflight wifi service                 0
# Departure/Arrival time convenient     0
# Ease of Online booking                0
# Gate location                         0
# Food and drink                        0
# Online boarding                       0
# Seat comfort                          0
# Inflight entertainment                0
# On-board service                      0
# Leg room service                      0
# Baggage handling                      0
# Checkin service                       0
# Inflight service                      0
# Cleanliness                           0
# Departure Delay in Minutes            0
# ...

# %%
# Replacing missing values

# %%
df['Arrival Delay in Minutes'].fillna(df['Arrival Delay in Minutes'].mean(), inplace=True)

# %%
number_of_elements = len(df['Arrival Delay in Minutes'])
print("Number of elements: ", number_of_elements)
#number of elements per category
print(df['Arrival Delay in Minutes'].value_counts())
#Replace and display the values
df['Arrival Delay in Minutes'].fillna('G6',inplace=True)
df.tail()
df.head()
# Out:
# Number of elements:  25976
# 0.0      14594
# 1.0        536
# 2.0        523
# 3.0        490
# 4.0        466
#          ...
# 227.0        1
# 237.0        1
# 333.0        1
# 940.0        1
# 748.0        1
# Name: Arrival Delay in Minutes, Length: 321, dtype: int64
#    Unnamed: 0     id  ... Arrival Delay in Minutes             satisfaction
# 0           0  19556  ...                     44.0                satisfied
# 1           1  90035  ...                      0.0                satisfied
# 2           2  12360  ...                      0.0  neutral or dissatisfied
# 3           3  77959  ...                      6.0                satisfied
# 4           4  36875  ...                     20.0                satisfied
#
# [5 rows x 25 columns]

# %%
# Data Visualization

# %%
# Correlation between Sex and Age

# %%
grid = sns.FacetGrid(df, row="Gender", size=2.2, aspect=1.6)
grid.map(sns.barplot, "Age", alpha=.5, ci=None)
grid.add_legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:670: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
# Correlation of Gender and Age in Histogram with 20 bins

# %%
g=sns.FacetGrid(df, col='Gender')
g.map(plt.hist,'Age',bins=20)

# %%
# Correlation of Gender and Age in Histogram with 10 bins

# %%
g=sns.FacetGrid(df, col='Gender')
g.map(plt.hist,'Age',bins=5)

# %%
# Correlation of Customer Type with flight class

# %%
g=sns.FacetGrid(df, col='Customer Type')
g.map(plt.hist,'Class',bins=20)

# %%
# Correlation of Customer Type with Food and drinks purchased

# %%
g=sns.FacetGrid(df, col='Customer Type')
g.map(plt.hist,'Food and drink',bins=20)

# %%
def plot_correlation_map(df):
  corr = df.corr() 
  s, ax = plt.subplots(figsize =(12, 10))
  cmap = sns.diverging_palette(220, 10, as_cmap = True)
  s = sns.heatmap(corr, cmap = cmap, square=True, cbar_kws={'shrink': .9}, ax=ax, annot = True, annot_kws = {'fontsize': 12})

# %%
df.head()
# Out:
#    Unnamed: 0     id  ... Arrival Delay in Minutes             satisfaction
# 0           0  19556  ...                     44.0                satisfied
# 1           1  90035  ...                      0.0                satisfied
# 2           2  12360  ...                      0.0  neutral or dissatisfied
# 3           3  77959  ...                      6.0                satisfied
# 4           4  36875  ...                     20.0                satisfied
#
# [5 rows x 25 columns]

# %%
df.tail()
# Out:
#        Unnamed: 0     id  ... Arrival Delay in Minutes             satisfaction
# 25971       25971  78463  ...                      0.0  neutral or dissatisfied
# 25972       25972  71167  ...                      0.0                satisfied
# 25973       25973  37675  ...                      0.0  neutral or dissatisfied
# 25974       25974  90086  ...                      0.0                satisfied
# 25975       25975  34799  ...                      0.0  neutral or dissatisfied
#
# [5 rows x 25 columns]

# %%
#the impact of class on the variable Customer Type
cleanup={"Customer Type":{"Loyal Customer":1, "disloyal Customer":0}}  # at first, let's convert Customer Type to numerical format
df.replace(cleanup, inplace=True)
df[["Class", "Customer Type"]].groupby(["Class"], as_index=True).mean()
# Out:
#           Customer Type
# Class
# Business       0.849940
# Eco            0.764441
# Eco Plus       0.895670

# %%
df['Arrival Delay in Minutes'].values
# Out:
# array([44.,  0.,  0., ...,  0.,  0.,  0.])

# %%
# Converting categorical variable into a number.

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
df['Class']=encoder.fit_transform(df['Class'])
df
# Out:
#        Unnamed: 0     id  ...  Arrival Delay in Minutes             satisfaction
# 0               0  19556  ...                        45                satisfied
# 1               1  90035  ...                         0                satisfied
# 2               2  12360  ...                         0  neutral or dissatisfied
# 3               3  77959  ...                         6                satisfied
# 4               4  36875  ...                        21                satisfied
# ...           ...    ...  ...                       ...                      ...
# 25971       25971  78463  ...                         0  neutral or dissatisfied
# 25972       25972  71167  ...                         0                satisfied
# 25973       25973  37675  ...                         0  neutral or dissatisfied
# 25974       25974  90086  ...                         0                satisfied
# 25975       25975  34799  ...                         0  neutral or dissatisfied
#
# ...

# %%
#droping the colum where any elemnts are missing
df.dropna(axis=1, how='any')
# Out:
#        Unnamed: 0     id  ...  Arrival Delay in Minutes             satisfaction
# 0               0  19556  ...                        45                satisfied
# 1               1  90035  ...                         0                satisfied
# 2               2  12360  ...                         0  neutral or dissatisfied
# 3               3  77959  ...                         6                satisfied
# 4               4  36875  ...                        21                satisfied
# ...           ...    ...  ...                       ...                      ...
# 25971       25971  78463  ...                         0  neutral or dissatisfied
# 25972       25972  71167  ...                         0                satisfied
# 25973       25973  37675  ...                         0  neutral or dissatisfied
# 25974       25974  90086  ...                         0                satisfied
# 25975       25975  34799  ...                         0  neutral or dissatisfied
#
# ...

# %%
df.dropna(thresh=80)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, id, Gender, Customer Type, Age, Type of Travel, Class, Flight Distance, Inflight wifi service, Departure/Arrival time convenient, Ease of Online booking, Gate location, Food and drink, Online boarding, Seat comfort, Inflight entertainment, On-board service, Leg room service, Baggage handling, Checkin service, Inflight service, Cleanliness, Departure Delay in Minutes, Arrival Delay in Minutes, satisfaction]
# Index: []
